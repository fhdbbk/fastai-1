# %% [markdown]
# <a href="https://colab.research.google.com/github/fhdbbk/fastai-1/blob/main/04_pet_breeds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hide
# !pip install -Uqq fastbook
import fastbook
# fastbook.setup_book()
# Out:
#      |████████████████████████████████| 720 kB 5.3 MB/s
#      |████████████████████████████████| 46 kB 3.7 MB/s
#      |████████████████████████████████| 186 kB 49.4 MB/s
#      |████████████████████████████████| 1.2 MB 32.2 MB/s
#      |████████████████████████████████| 56 kB 4.0 MB/s
#      |████████████████████████████████| 51 kB 290 kB/s

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
fastbook.__version__
# Out:
# '0.0.18'

# %%
import fastai
fastai.__version__
# Out:
# '2.5.2'

# %% [markdown]
# # Image Classification

# %% [markdown]
# ## From Dogs and Cats to Pet Breeds

# %%
from fastai.vision.all import *
path = untar_data(URLs.PETS)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='811712512' class='' max='811706944' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [811712512/811706944 00:13<00:00]
#     </div>

# %%
path.absolute()
# Out:
# Path('/root/.fastai/data/oxford-iiit-pet')

# %%
#hide
Path.BASE_PATH = path

# %%
Path.BASE_PATH
# Out:
# Path('.')

# %%
print(Path.BASE_PATH)
# print(Path.BASE_PATH.absolute())
# Out:
# /root/.fastai/data/oxford-iiit-pet

# %%
path.ls()
# Out:
# (#2) [Path('annotations'),Path('images')]

# %%
(path/"images").ls()
# Out:
# (#7393) [Path('images/shiba_inu_25.jpg'),Path('images/keeshond_106.jpg'),Path('images/Siamese_47.jpg'),Path('images/basset_hound_64.jpg'),Path('images/Persian_258.jpg'),Path('images/havanese_35.jpg'),Path('images/shiba_inu_3.jpg'),Path('images/german_shorthaired_46.jpg'),Path('images/Persian_114.jpg'),Path('images/British_Shorthair_2.jpg')...]

# %%
fname = (path/"images").ls()[0]
fname
# Out:
# Path('images/shiba_inu_25.jpg')

# %%
re.findall(r'(.+)_\d+.jpg$', fname.name)
# Out:
# ['shiba_inu']

# %%
RegexLabeller(r'(.+)_\d+.jpg$')(fname.name)
# Out:
# 'shiba_inu'

# %%
# This is how RandomSplitter works. Here 5 is the number of image files
x = torch.randperm(5)
print(x)
x = x.numpy()
print(x)
x = list(x)
print(x)
x = L(x)
print(x)
cut = int(0.2 * 5)
print(cut)
x[cut:], x[:cut]
# Out:
# tensor([2, 4, 3, 0, 1])
# [2 4 3 0 1]
# [2, 4, 3, 0, 1]
# [2, 4, 3, 0, 1]
# 1
# ((#4) [4,3,0,1], (#1) [2])

# %%
RandomSplitter??

# %%
# here min_scale=0.75 in aug_transforms indicates that RandomResizedCrop will be used for resizing in batch
pets = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=RandomSplitter(seed=42),
                 get_y=using_attr(RegexLabeller(r'(.+)_\d+.jpg$'), 'name'),
                 item_tfms=Resize(460),
                 batch_tfms=aug_transforms(size=224, min_scale=0.75))
dls = pets.dataloaders(path/"images")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1023: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  /pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:760.)
#   ret = func(*args, **kwargs)

# %%
wd = 100
hd = -100
w_rand = (0, wd)
h_rand = (hd, -1)
print(random.randint(*w_rand))
tl = fastuple(random.randint(*w_rand), random.randint(*h_rand))
print(tl)
print(tl.max(0))
c = tl.max(0)
(*c, *c.add((500, 500)).min((600, 400)))
# Out:
# 54
# (4, -97)
# (4, 0)
# (4, 0, 504, 400)

# %%
img = PILImage(PILImage.create(fname).resize((600,400)))
img
# Out:
# PILImage mode=RGB size=600x400

# %%
img_r = Resize(460)(img)
print(img_r.shape)
reimg_r
# Out:
# (460, 460)
# PILImage mode=RGB size=460x460

# %%
RandomResizedCrop??

# %% [markdown]
# * In Resize with squish method, when size which is 460 here, a simple interpolation is performed which enlarges the smaller dimension and squishes the larger dimension.
# * In pad method, image is resized till the larger dimension of the image matches with the new size and the smaller dimension is padded.
# * In crop method, image is resized till the smaller dimension of the image matches with the new size and a random crop is performed for the larger dimension. Default method is crop.

# %%
random.uniform(0.08, 1.0)
# Out:
# 0.7252189757030171

# %%
random.normalvariate(1.0, 0.2)
# Out:
# 1.105669339596199

# %% [markdown]
# ## Presizing

# %%
download_url??

# %%
ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']
bear_path = 'images'
if not os.path.exists(bear_path):
  os.mkdir(bear_path)
dest = 'images/grizzly.jpg'
download_url(ims[0], dest)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='704512' class='' max='697626' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.99% [704512/697626 00:00<00:00]
#     </div>
# Path('images/grizzly.jpg')

# %%
[(Path.cwd()/'images'/'grizzly.jpg')]*10
# Out:
# [Path('/content/images/grizzly.jpg'),
#  Path('/content/images/grizzly.jpg'),
#  Path('/content/images/grizzly.jpg'),
#  Path('/content/images/grizzly.jpg'),
#  Path('/content/images/grizzly.jpg'),
#  Path('/content/images/grizzly.jpg'),
#  Path('/content/images/grizzly.jpg'),
#  Path('/content/images/grizzly.jpg'),
#  Path('/content/images/grizzly.jpg'),
#  Path('/content/images/grizzly.jpg')]

# %%
dblock1 = DataBlock(blocks=(ImageBlock, CategoryBlock),
                   get_y=parent_label,
                   item_tfms=Resize(460))
dls1 = dblock1.dataloaders([(Path.cwd()/'images'/'grizzly.jpg')]*100, bs=8)
dls1.train.get_idxs = lambda: Inf.ones
x,y = dls1.valid.one_batch()
_,axs = subplots(1, 2)

x1 = TensorImage(x.clone())
x1 = x1.affine_coord(sz=224)
x1 = x1.rotate(draw=30, p=1.)
x1 = x1.zoom(draw=1.2, p=1.)
x1 = x1.warp(draw_x=-0.2, draw_y=0.2, p=1.)

tfms = setup_aug_tfms([Rotate(draw=30, p=1, size=224), Zoom(draw=1.2, p=1., size=224),
                       Warp(draw_x=-0.2, draw_y=0.2, p=1., size=224)])
x = Pipeline(tfms)(x)
#x.affine_coord(coord_tfm=coord_tfm, sz=size, mode=mode, pad_mode=pad_mode)
TensorImage(x[0]).show(ctx=axs[0])
TensorImage(x1[0]).show(ctx=axs[1]);

# %% [markdown]
# ### Checking and Debugging a DataBlock

# %%
dls.show_batch(nrows=2, ncols=3)

# %%
pets1 = DataBlock(blocks = (ImageBlock, CategoryBlock),
                 get_items=get_image_files, 
                 splitter=RandomSplitter(seed=42),
                 get_y=using_attr(RegexLabeller(r'(.+)_\d+.jpg$'), 'name'))
pets1.summary(path/"images")
# Out:
# Setting-up type transforms pipelines
# ...
# Found 7390 items
# 2 datasets of sizes 5912,1478
# Setting up Pipeline: PILBase.create
# Setting up Pipeline: partial -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
#
# Building one sample
#   Pipeline: PILBase.create
#     starting from
#       /root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_110.jpg
#     applying PILBase.create gives
#       PILImage mode=RGB size=363x500
#   Pipeline: partial -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
#     starting from
#       /root/.fastai/data/oxford-iiit-pet/images/german_shorthaired_110.jpg
#     applying partial gives
#       german_shorthaired
#     applying Categorize -- {'vocab': None, 'sort': True, 'add_na': False} gives
#       TensorCategory(20)
#
# Final sample: (PILImage mode=RGB size=363x500, TensorCategory(20))
#
#
# ...
# Found 7390 items
# 2 datasets of sizes 5912,1478
# Setting up Pipeline: PILBase.create
# ...

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(2)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.485121</td>
#       <td>0.324151</td>
#       <td>0.104195</td>
#       <td>01:55</td>
#     </tr>
#   </tbody>
# ...

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %% [markdown]
# ## Cross-Entropy Loss

# %% [markdown]
# ### Viewing Activations and Labels

# %%
x,y = dls.one_batch()

# %%
y
# Out:
# TensorCategory([24, 31, 36, 27, 23, 18,  5,  1,  4, 13, 34,  4, 26, 34, 14, 32,  0, 23, 10, 16,  8,  3,  1, 15, 11, 17, 14,  6,  4,  6, 31, 33,  9, 28,  9, 17, 31, 11, 30,  2, 29, 30,  1, 21, 24, 17, 16, 28,
#         14,  7,  3,  6, 23, 16, 21, 34, 11,  8, 34, 20,  9, 31,  5, 20], device='cuda:0')

# %%
learn.get_preds??

# %%
# learn.get_preds applies sigmoid activation to results and hence we get probabilities from 0 to 1
preds,_ = learn.get_preds(dl=[(x,y)])
preds[0]
# Out:
# tensor([6.6062e-10, 2.2100e-09, 3.4884e-06, 1.4138e-09, 6.6110e-08, 7.4255e-08, 1.7117e-07, 1.4259e-06, 8.3112e-08, 4.0282e-09, 3.3694e-09, 6.2806e-09, 4.5674e-09, 1.5020e-08, 7.0349e-09, 3.9418e-09,
#         1.3327e-09, 1.6206e-09, 5.8762e-10, 7.7302e-09, 5.6033e-08, 2.1839e-07, 1.4738e-08, 9.7577e-07, 9.9998e-01, 2.2299e-06, 5.2291e-09, 6.9602e-08, 9.3506e-06, 1.8144e-06, 1.6203e-08, 3.8327e-06,
#         1.6967e-08, 9.6336e-08, 2.2570e-08, 2.0689e-08, 3.6646e-08])

# %%
len(preds[0]),preds[0].sum()
# Out:
# (37, tensor(1.0000))

# %% [markdown]
# ### Softmax

# %%
plot_function(torch.sigmoid, min=-4,max=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/fastbook/__init__.py:74: UserWarning: Not providing a value for linspace's steps is deprecated and will throw a runtime error in a future release. This warning will appear only once per process. (Triggered internally at  /pytorch/aten/src/ATen/native/RangeFactories.cpp:25.)
#   x = torch.linspace(min,max)

# %%
#hide
torch.random.manual_seed(42);

# %%
acts = torch.randn((6,2))*2
acts
# Out:
# tensor([[ 0.6734,  0.2576],
#         [ 0.4689,  0.4607],
#         [-2.2457, -0.3727],
#         [ 4.4164, -1.2760],
#         [ 0.9233,  0.5347],
#         [ 1.0698,  1.6187]])

# %%
acts.sigmoid()
# Out:
# tensor([[0.6623, 0.5641],
#         [0.6151, 0.6132],
#         [0.0957, 0.4079],
#         [0.9881, 0.2182],
#         [0.7157, 0.6306],
#         [0.7446, 0.8346]])

# %%
(acts[:,0]-acts[:,1]).sigmoid()
# Out:
# tensor([0.6025, 0.5021, 0.1332, 0.9966, 0.5959, 0.3661])

# %%
sm_acts = torch.softmax(acts, dim=1)
sm_acts
# Out:
# tensor([[0.6025, 0.3975],
#         [0.5021, 0.4979],
#         [0.1332, 0.8668],
#         [0.9966, 0.0034],
#         [0.5959, 0.4041],
#         [0.3661, 0.6339]])

# %% [markdown]
# ### Log Likelihood

# %%
targ = tensor([0,1,0,1,1,0])

# %%
sm_acts
# Out:
# tensor([[0.6025, 0.3975],
#         [0.5021, 0.4979],
#         [0.1332, 0.8668],
#         [0.9966, 0.0034],
#         [0.5959, 0.4041],
#         [0.3661, 0.6339]])

# %%
idx = range(6)
sm_acts[idx, targ]
# Out:
# tensor([0.6025, 0.4979, 0.1332, 0.0034, 0.4041, 0.3661])

# %%
from IPython.display import HTML
df = pd.DataFrame(sm_acts, columns=["3","7"])
df['targ'] = targ
df['idx'] = idx
df['loss'] = sm_acts[range(6), targ]
t = df.style.hide_index()
#To have html code compatible with our script
html = t._repr_html_().split('</style>')[1]
html = re.sub(r'<table id="([^"]+)"\s*>', r'<table >', html)
display(HTML(html))
# Out:
# <table ><thead>    <tr>        <th class="col_heading level0 col0" >3</th>        <th class="col_heading level0 col1" >7</th>        <th class="col_heading level0 col2" >targ</th>        <th class="col_heading level0 col3" >idx</th>        <th class="col_heading level0 col4" >loss</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_666a0cee_0db1_11ec_90e8_0242ac1c0002row0_col0" class="data row0 col0" >0.602469</td>
#                         <td id="T_666a0cee_0db1_11ec_90e8_0242ac1c0002row0_col1" class="data row0 col1" >0.397531</td>
#                         <td id="T_666a0cee_0db1_11ec_90e8_0242ac1c0002row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_666a0cee_0db1_11ec_90e8_0242ac1c0002row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_666a0cee_0db1_11ec_90e8_0242ac1c0002row0_col4" class="data row0 col4" >0.602469</td>
#             </tr>
#             <tr>
# ...

# %%
-sm_acts[idx, targ]
# Out:
# tensor([-0.6025, -0.4979, -0.1332, -0.0034, -0.4041, -0.3661])

# %%
F.nll_loss(sm_acts, targ, reduction='none')
# Out:
# tensor([-0.6025, -0.4979, -0.1332, -0.0034, -0.4041, -0.3661])

# %% [markdown]
# ### Taking the Log

# %%
plot_function(torch.log, min=0,max=4)

# %%
loss_func = nn.CrossEntropyLoss()

# %%
loss_func(acts, targ)
# Out:
# tensor(1.8045)

# %%
F.cross_entropy(acts, targ)
# Out:
# tensor(1.8045)

# %%
nn.CrossEntropyLoss(reduction='none')(acts, targ)
# Out:
# tensor([0.5067, 0.6973, 2.0160, 5.6958, 0.9062, 1.0048])

# %%
sm_acts_log = torch.log(sm_acts)
sm_acts_log
# Out:
# tensor([[-5.0672e-01, -9.2248e-01],
#         [-6.8903e-01, -6.9729e-01],
#         [-2.0160e+00, -1.4293e-01],
#         [-3.3658e-03, -5.6958e+00],
#         [-5.1760e-01, -9.0621e-01],
#         [-1.0048e+00, -4.5589e-01]])

# %%
-sm_acts_log[idx, targ]
# Out:
# tensor([0.5067, 0.6973, 2.0160, 5.6958, 0.9062, 1.0048])

# %% [markdown]
# F.nll_loss(log(sm_acts[idx, targ]), targ) = -(log(sm_acts[idx, targ])) = CrossEntropyLoss(acts, targ)

# %%
F.nll_loss(sm_acts_log, targ, reduction='none')
# Out:
# tensor([0.5067, 0.6973, 2.0160, 5.6958, 0.9062, 1.0048])

# %% [markdown]
# ## Model Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=5)
# Out:
# [('Bengal', 'Egyptian_Mau', 6),
#  ('american_bulldog', 'american_pit_bull_terrier', 6),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 6),
#  ('British_Shorthair', 'Russian_Blue', 5),
#  ('Ragdoll', 'Birman', 5)]

# %% [markdown]
# ## Improving Our Model

# %% [markdown]
# ### The Learning Rate Finder

# %% [markdown]
# Model gets worse because of large learning rate of 0.1

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(1, base_lr=0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.510115</td>
#       <td>7.434442</td>
#       <td>0.629229</td>
#       <td>01:11</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.252499</td>
#       <td>4.006604</td>
#       <td>0.500000</td>
#       <td>01:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
lr_min = learn.lr_find()

# %%
learn.lr_find??

# %%
# type(lr_min.SuggestedLRs)
print(lr_min)
# Out:
# SuggestedLRs(valley=0.001737800776027143)

# %%
# print(f"Minimum/10: {lr_min:.2e})#, steepest point: {lr_steep:.2e}")

# %% [markdown]
# Picking a learning rate of 3e-3 which is just ahead of valley point

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(2, base_lr=3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.332852</td>
#       <td>0.331776</td>
#       <td>0.106225</td>
#       <td>01:12</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.557722</td>
#       <td>0.345283</td>
#       <td>0.108254</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.325486</td>
#       <td>0.218269</td>
#       <td>0.069689</td>
#       <td>01:17</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Unfreezing and Transfer Learning

# %%
learn.fine_tune??

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fit_one_cycle(3, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.173612</td>
#       <td>0.337965</td>
#       <td>0.107578</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.517737</td>
#       <td>0.236316</td>
#       <td>0.076455</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.330608</td>
#       <td>0.198287</td>
#       <td>0.066982</td>
#       <td>01:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=5.754399353463668e-06)

# %%
learn.fit_one_cycle(6, lr_max=1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.269892</td>
#       <td>0.195673</td>
#       <td>0.065629</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.258313</td>
#       <td>0.190014</td>
#       <td>0.060893</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.222577</td>
#       <td>0.184380</td>
#       <td>0.057510</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.205966</td>
#       <td>0.177875</td>
#       <td>0.058863</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.191876</td>
#       <td>0.175625</td>
#       <td>0.056834</td>
#       <td>01:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# ### Discriminative Learning Rates

# %%
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fit_one_cycle(3, 3e-3)
learn.unfreeze()
learn.fit_one_cycle(12, lr_max=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.169095</td>
#       <td>0.305806</td>
#       <td>0.086604</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.522109</td>
#       <td>0.251131</td>
#       <td>0.091340</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.318265</td>
#       <td>0.202452</td>
#       <td>0.064953</td>
#       <td>01:10</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot_loss()

# %% [markdown]
# ### Selecting the Number of Epochs

# %% [markdown]
# ### Deeper Architectures

# %%
from fastai.callback.fp16 import *
# learn = cnn_learner(dls, resnet50, metrics=error_rate).to_fp16()
learn = cnn_learner(dls, resnet34, metrics=error_rate).to_fp16()
learn.fine_tune(6, freeze_epochs=3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.543142</td>
#       <td>0.558717</td>
#       <td>0.161705</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.936462</td>
#       <td>0.307218</td>
#       <td>0.098782</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.552057</td>
#       <td>0.291184</td>
#       <td>0.102165</td>
#       <td>01:03</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Why do we first resize to a large size on the CPU, and then to a smaller size on the GPU?
# 1. If you are not familiar with regular expressions, find a regular expression tutorial, and some problem sets, and complete them. Have a look on the book's website for suggestions.
# 1. What are the two ways in which data is most commonly provided, for most deep learning datasets?
# 1. Look up the documentation for `L` and try using a few of the new methods that it adds.
# 1. Look up the documentation for the Python `pathlib` module and try using a few methods of the `Path` class.
# 1. Give two examples of ways that image transformations can degrade the quality of the data.
# 1. What method does fastai provide to view the data in a `DataLoaders`?
# 1. What method does fastai provide to help you debug a `DataBlock`?
# 1. Should you hold off on training a model until you have thoroughly cleaned your data?
# 1. What are the two pieces that are combined into cross-entropy loss in PyTorch?
# 1. What are the two properties of activations that softmax ensures? Why is this important?
# 1. When might you want your activations to not have these two properties?
# 1. Calculate the `exp` and `softmax` columns of <<bear_softmax>> yourself (i.e., in a spreadsheet, with a calculator, or in a notebook).
# 1. Why can't we use `torch.where` to create a loss function for datasets where our label can have more than two categories?
# 1. What is the value of log(-2)? Why?
# 1. What are two good rules of thumb for picking a learning rate from the learning rate finder?
# 1. What two steps does the `fine_tune` method do?
# 1. In Jupyter Notebook, how do you get the source code for a method or function?
# 1. What are discriminative learning rates?
# 1. How is a Python `slice` object interpreted when passed as a learning rate to fastai?
# 1. Why is early stopping a poor choice when using 1cycle training?
# 1. What is the difference between `resnet50` and `resnet101`?
# 1. What does `to_fp16` do?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Find the paper by Leslie Smith that introduced the learning rate finder, and read it.
# 1. See if you can improve the accuracy of the classifier in this chapter. What's the best accuracy you can achieve? Look on the forums and the book's website to see what other students have achieved with this dataset, and how they did it.
